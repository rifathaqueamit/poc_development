# %% [markdown]
# <a href="https://colab.research.google.com/github/rifathaqueamit/poc_development/blob/develop/poc_v_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Demonstration of the POC for searching content inside video</h1>

# %% [markdown]
# Prerequisites
#
#
# 1.  Upload the required model with name "model.tflite"
# 2.  Upload the input video inside folder "input_videos"
#
# Update : V5 (15th Aug, 2023)

# %%
# @title 1. Install dependencies
# !pip install -U -q "tf-models-official"
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy

# %%
# @title 2. Import dependencies
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import mediapy as media
import numpy as np
import PIL
import pandas as pd
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_hub as hub
import tqdm
import absl.logging
import random
import re
import tempfile
import ssl
import cv2
import imageio
from IPython import display
from urllib import request

tf.get_logger().setLevel('ERROR')
absl.logging.set_verbosity(absl.logging.ERROR)
mpl.rcParams.update({
    'font.size': 10,
})

# %%
# @title 3. Define constants (if required)
#Constants
input_videos_path = "input_videos"
output_videos_path = "output_videos"
model_frame_width = 224
model_frame_height = 224
video_fps = 5
seconds_per_segments = 5
threshold = 50
frames_per_video = seconds_per_segments * video_fps

# %%
# @title 4. Helper functions

# Download Kinetics 600 label map
# !wget https://raw.githubusercontent.com/tensorflow/models/f8af2291cced43fc9f1d9b41ddbf772ae7b0d7d2/official/projects/movinet/files/kinetics_600_labels.txt -O labels.txt -q

with tf.io.gfile.GFile('labels.txt') as f:
  lines = f.readlines()
  KINETICS_600_LABELS_LIST = [line.strip() for line in lines]
  KINETICS_600_LABELS = tf.constant(KINETICS_600_LABELS_LIST)

def get_top_k(probs, k=5, label_map=KINETICS_600_LABELS):
  """Outputs the top k model labels and probabilities on the given video."""
  top_predictions = tf.argsort(probs, axis=-1, direction='DESCENDING')[:k]
  top_labels = tf.gather(label_map, top_predictions, axis=-1)
  top_labels = [label.decode('utf8') for label in top_labels.numpy()]
  top_probs = tf.gather(probs, top_predictions, axis=-1).numpy()
  return tuple(zip(top_labels, top_probs))

def predict_top_k(model, video, k=5, label_map=KINETICS_600_LABELS):
  """Outputs the top k model labels and probabilities on the given video."""
  outputs = model.predict(video[tf.newaxis])[0]
  probs = tf.nn.softmax(outputs)
  return get_top_k(probs, k=k, label_map=label_map)

def get_top_k_streaming_labels(probs, k=5, label_map=KINETICS_600_LABELS_LIST):
  """Returns the top-k labels over an entire video sequence.

  Args:
    probs: probability tensor of shape (num_frames, num_classes) that represents
      the probability of each class on each frame.
    k: the number of top predictions to select.
    label_map: a list of labels to map logit indices to label strings.

  Returns:
    a tuple of the top-k probabilities, labels, and logit indices
  """
  top_categories_last = tf.argsort(probs, -1, 'DESCENDING')[-1, :1]
  categories = tf.argsort(probs, -1, 'DESCENDING')[:, :k]
  categories = tf.reshape(categories, [-1])

  counts = sorted([
      (i.numpy(), tf.reduce_sum(tf.cast(categories == i, tf.int32)).numpy())
      for i in tf.unique(categories)[0]
  ], key=lambda x: x[1], reverse=True)

  top_probs_idx = tf.constant([i for i, _ in counts[:k]])
  top_probs_idx = tf.concat([top_categories_last, top_probs_idx], 0)
  top_probs_idx = tf.unique(top_probs_idx)[0][:k+1]

  top_probs = tf.gather(probs, top_probs_idx, axis=-1)
  top_probs = tf.transpose(top_probs, perm=(1, 0))
  top_labels = tf.gather(label_map, top_probs_idx, axis=0)
  top_labels = [label.decode('utf8') for label in top_labels.numpy()]

  return top_probs, top_labels, top_probs_idx

# Utilities to open video files using CV2
def crop_center_square(frame):
  y, x = frame.shape[0:2]
  min_dim = min(y, x)
  start_x = (x // 2) - (min_dim // 2)
  start_y = (y // 2) - (min_dim // 2)
  return frame[start_y:start_y+min_dim,start_x:start_x+min_dim]

def load_video(path, max_frames=0, resize=(model_frame_width, model_frame_height)):
  cap = cv2.VideoCapture(path)
  frames = []
  try:
    while True:
      ret, frame = cap.read()
      if not ret:
        break
      frame = crop_center_square(frame)
      frame = cv2.resize(frame, resize)
      frame = frame[:, :, [2, 1, 0]]
      frames.append(frame)

      if len(frames) == max_frames:
        break
  finally:
    cap.release()
  return np.array(frames) / 255.0

# detect and print 5 probabilities
def detect(name, video):
  print("...")
  print("Detecting " + name + "...")
  init_states = {
    name: tf.zeros(x['shape'], dtype=x['dtype'])
    for name, x in runner.get_input_details().items()
  }
  del init_states['image']

  clips = video
  states = init_states
  for clip in clips:
    outputs = runner(**states, image=clip)
    logits = outputs.pop('logits')[0]
    states = outputs

  probs = tf.nn.softmax(logits)
  top_k = get_top_k(probs)
  print()
  for label, prob in top_k:
    print(label, prob)

# %%
# @title 5. Load pre-trained model
# Create the interpreter and signature runner
interpreter = tf.lite.Interpreter(model_path="model.tflite")
runner = interpreter.get_signature_runner()

# %%
# @title 6. Make necessary folders
if os.path.exists(input_videos_path) == False:
  os.mkdir(input_videos_path)

if os.path.exists(output_videos_path) == False:
  os.mkdir(output_videos_path)

# %%
# @title 7. Collect input videos (Mp4 only)
input_videos = []

for file in os.listdir("input_videos"):
    if file.endswith(".mp4"):
        input_videos.append(file)

if len(input_videos) == 0:
  print("There is no input videos")
else:
  print(input_videos)
# Out:
# ['received_1256249425052246.mp4', 'received_1623461488133843.mp4', 'received_277972764930844.mp4', 'received_1452332362219383.mp4', 'received_263262066473754.mp4', 'received_592475249758361.mp4', 'received_948054863158482.mp4', 'received_308575671655388.mp4', 'received_1035295351175161.mp4', 'received_256168027307762.mp4', 'received_824546655998330.mp4']

# %%
# @title 8. Convert the input mp4 video into AVI format
output_videos = []
for input_video in input_videos:
  input_path = input_videos_path + "/" + input_video
  path, filename_ext = os.path.split(input_path)
  filename = os.path.splitext(filename_ext)
  output_path = output_videos_path + "/" + filename[0] + ".avi"
  if os.path.exists(output_path):
    os.remove(output_path)
  print("Input : ", input_path)
  print("Output : ", output_path)
  # !ffmpeg -i $input_path -filter:v fps=$video_fps $output_path
  output_videos.append(output_path)
# Out:
# Input :  input_videos/received_1256249425052246.mp4
# Output :  output_videos/received_1256249425052246.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_1256249425052246.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:15.19, start: 0.000000, bitrate: 1242 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 368x656 [SAR 1:1 DAR 23:41], 1169 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_1256249425052246.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 368x656 [SAR 1:1 DAR 23:41], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=   76 fps= 47 q=16.8 Lsize=     792kB time=00:00:15.20 bitrate= 426.9kbits/s speed=9.32x
# video:529kB audio:238kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.299015%
# Input :  input_videos/received_1623461488133843.mp4
# Output :  output_videos/received_1623461488133843.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_1623461488133843.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:58.96, start: 0.000000, bitrate: 554 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 368x656 [SAR 1:1 DAR 23:41], 481 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_1623461488133843.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 368x656 [SAR 1:1 DAR 23:41], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  295 fps= 88 q=9.1 Lsize=    2575kB time=00:00:59.00 bitrate= 357.5kbits/s speed=17.6x
# video:1583kB audio:922kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.789414%
# Input :  input_videos/received_277972764930844.mp4
# Output :  output_videos/received_277972764930844.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_277972764930844.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:27.40, start: 0.000000, bitrate: 994 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 368x656 [SAR 1:1 DAR 23:41], 921 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_277972764930844.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 368x656 [SAR 1:1 DAR 23:41], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  137 fps= 36 q=10.9 Lsize=    1270kB time=00:00:27.40 bitrate= 379.8kbits/s speed=7.29x
# video:804kB audio:429kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.060858%
# Input :  input_videos/received_1452332362219383.mp4
# Output :  output_videos/received_1452332362219383.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_1452332362219383.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:21.67, start: 0.000000, bitrate: 536 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 368x656 [SAR 1:1 DAR 23:41], 463 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_1452332362219383.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 368x656 [SAR 1:1 DAR 23:41], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  108 fps= 32 q=8.4 Lsize=    1035kB time=00:00:21.65 bitrate= 391.4kbits/s speed=6.32x
# video:664kB audio:339kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.179348%
# Input :  input_videos/received_263262066473754.mp4
# Output :  output_videos/received_263262066473754.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_263262066473754.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:03:07.57, start: 0.000000, bitrate: 1011 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 640x368 [SAR 1:1 DAR 40:23], 939 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_263262066473754.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 640x368 [SAR 1:1 DAR 40:23], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  938 fps= 41 q=2.0 Lsize=    7601kB time=00:03:07.60 bitrate= 331.9kbits/s speed=8.25x
# video:4469kB audio:2931kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.713843%
# Input :  input_videos/received_592475249758361.mp4
# Output :  output_videos/received_592475249758361.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_592475249758361.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:58.96, start: 0.000000, bitrate: 1362 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 368x656 [SAR 1:1 DAR 23:41], 1290 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_592475249758361.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 368x656 [SAR 1:1 DAR 23:41], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  295 fps= 77 q=22.0 Lsize=    2522kB time=00:00:59.00 bitrate= 350.1kbits/s speed=15.5x
# video:1530kB audio:922kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.849619%
# Input :  input_videos/received_948054863158482.mp4
# Output :  output_videos/received_948054863158482.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_948054863158482.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:15.05, start: 0.000000, bitrate: 750 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 368x656 [SAR 1:1 DAR 23:41], 677 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_948054863158482.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 368x656 [SAR 1:1 DAR 23:41], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=   75 fps=0.0 q=10.0 Lsize=     749kB time=00:00:15.02 bitrate= 408.7kbits/s speed=18.2x
# video:489kB audio:236kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.469961%
# Input :  input_videos/received_308575671655388.mp4
# Output :  output_videos/received_308575671655388.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_308575671655388.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:13.23, start: 0.000000, bitrate: 684 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 368x640 [SAR 1:1 DAR 23:40], 616 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_308575671655388.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 368x640 [SAR 1:1 DAR 23:40], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=   66 fps=0.0 q=9.2 Lsize=     707kB time=00:00:13.22 bitrate= 437.9kbits/s speed=  17x
# video:475kB audio:207kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.565127%
# Input :  input_videos/received_1035295351175161.mp4
# Output :  output_videos/received_1035295351175161.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_1035295351175161.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:37.50, start: 0.000000, bitrate: 1338 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 368x656 [SAR 1:1 DAR 23:41], 1265 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_1035295351175161.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 368x656 [SAR 1:1 DAR 23:41], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  188 fps= 79 q=21.5 Lsize=    1690kB time=00:00:37.60 bitrate= 368.1kbits/s speed=15.8x
# video:1055kB audio:587kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.926042%
# Input :  input_videos/received_256168027307762.mp4
# Output :  output_videos/received_256168027307762.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_256168027307762.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:15.30, start: 0.000000, bitrate: 1276 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 640x368 [SAR 1:1 DAR 40:23], 1202 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_256168027307762.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 640x368 [SAR 1:1 DAR 40:23], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=   77 fps= 44 q=21.2 Lsize=     791kB time=00:00:15.40 bitrate= 420.7kbits/s speed=8.88x
# video:525kB audio:240kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.482016%
# Input :  input_videos/received_824546655998330.mp4
# Output :  output_videos/received_824546655998330.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/received_824546655998330.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:50.30, start: 0.000000, bitrate: 1056 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/smpte170m), 640x368 [SAR 1:1 DAR 40:23], 984 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc59.37.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 64 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/received_824546655998330.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/smpte170m, progressive), 640x368 [SAR 1:1 DAR 40:23], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  251 fps= 50 q=16.5 Lsize=    2174kB time=00:00:50.28 bitrate= 354.1kbits/s speed=  10x
# video:1326kB audio:787kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.888996%

# %%
# @title 9. Load the videos and show
loaded_videos = []
for output_video in output_videos:
  loaded_video = load_video(output_video)
  media.show_video(loaded_video, fps=video_fps)
  print("video frames count, width, height, color : ", loaded_video.shape)
  loaded_videos.append((output_video, loaded_video))

# %%
# @title 10. Separate the videos in small segments
def separateVideoInSegments(name, video):
  print("separateVideoInSegments() : ", name)
  video_segments = []
  video_segments_playable = []

  for idx, frame in enumerate(loaded_video):
    video_id = int(idx / frames_per_video)
    try:
      casted_frame = tf.cast(frame, tf.float32)
      video_segments[video_id].append(casted_frame)
      video_segments_playable[video_id].append(frame)
    except IndexError:
      video_segments.append([casted_frame])
      video_segments_playable.append([frame])

  for idx, segment in enumerate(video_segments):
    print(">> Segment ", idx+1, ", total frames : ", len(segment))

  return (name, video_segments, video_segments_playable)

videos_information = []
for output_video, loaded_video in loaded_videos:
  videos_information.append(separateVideoInSegments(output_video, loaded_video))
# Out:
# separateVideoInSegments() :  output_videos/received_1256249425052246.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# >> Segment  4 , total frames :  1
# separateVideoInSegments() :  output_videos/received_1623461488133843.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# >> Segment  4 , total frames :  25
# >> Segment  5 , total frames :  25
# >> Segment  6 , total frames :  25
# >> Segment  7 , total frames :  25
# >> Segment  8 , total frames :  25
# >> Segment  9 , total frames :  25
# >> Segment  10 , total frames :  25
# >> Segment  11 , total frames :  25
# >> Segment  12 , total frames :  20
# separateVideoInSegments() :  output_videos/received_277972764930844.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# >> Segment  4 , total frames :  25
# >> Segment  5 , total frames :  25
# >> Segment  6 , total frames :  12
# separateVideoInSegments() :  output_videos/received_1452332362219383.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# >> Segment  4 , total frames :  25
# >> Segment  5 , total frames :  8
# separateVideoInSegments() :  output_videos/received_263262066473754.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# >> Segment  4 , total frames :  25
# >> Segment  5 , total frames :  25
# >> Segment  6 , total frames :  25
# >> Segment  7 , total frames :  25
# >> Segment  8 , total frames :  25
# >> Segment  9 , total frames :  25
# >> Segment  10 , total frames :  25
# >> Segment  11 , total frames :  25
# >> Segment  12 , total frames :  25
# >> Segment  13 , total frames :  25
# >> Segment  14 , total frames :  25
# >> Segment  15 , total frames :  25
# >> Segment  16 , total frames :  25
# >> Segment  17 , total frames :  25
# >> Segment  18 , total frames :  25
# >> Segment  19 , total frames :  25
# >> Segment  20 , total frames :  25
# >> Segment  21 , total frames :  25
# >> Segment  22 , total frames :  25
# >> Segment  23 , total frames :  25
# >> Segment  24 , total frames :  25
# >> Segment  25 , total frames :  25
# >> Segment  26 , total frames :  25
# >> Segment  27 , total frames :  25
# >> Segment  28 , total frames :  25
# >> Segment  29 , total frames :  25
# >> Segment  30 , total frames :  25
# >> Segment  31 , total frames :  25
# >> Segment  32 , total frames :  25
# >> Segment  33 , total frames :  25
# >> Segment  34 , total frames :  25
# >> Segment  35 , total frames :  25
# >> Segment  36 , total frames :  25
# >> Segment  37 , total frames :  25
# >> Segment  38 , total frames :  13
# separateVideoInSegments() :  output_videos/received_592475249758361.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# >> Segment  4 , total frames :  25
# >> Segment  5 , total frames :  25
# >> Segment  6 , total frames :  25
# >> Segment  7 , total frames :  25
# >> Segment  8 , total frames :  25
# >> Segment  9 , total frames :  25
# >> Segment  10 , total frames :  25
# >> Segment  11 , total frames :  25
# >> Segment  12 , total frames :  20
# separateVideoInSegments() :  output_videos/received_948054863158482.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# separateVideoInSegments() :  output_videos/received_308575671655388.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  16
# separateVideoInSegments() :  output_videos/received_1035295351175161.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# >> Segment  4 , total frames :  25
# >> Segment  5 , total frames :  25
# >> Segment  6 , total frames :  25
# >> Segment  7 , total frames :  25
# >> Segment  8 , total frames :  13
# separateVideoInSegments() :  output_videos/received_256168027307762.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# >> Segment  4 , total frames :  2
# separateVideoInSegments() :  output_videos/received_824546655998330.avi
# >> Segment  1 , total frames :  25
# >> Segment  2 , total frames :  25
# >> Segment  3 , total frames :  25
# >> Segment  4 , total frames :  25
# >> Segment  5 , total frames :  25
# >> Segment  6 , total frames :  25
# >> Segment  7 , total frames :  25
# >> Segment  8 , total frames :  25
# >> Segment  9 , total frames :  25
# >> Segment  10 , total frames :  25
# >> Segment  11 , total frames :  1

# %%
# @title 11. Define the detect function
def detectFirstPrint(video):
  init_states = {
    name: tf.zeros(x['shape'], dtype=x['dtype'])
    for name, x in runner.get_input_details().items()
  }
  del init_states['image']

  clips = video
  states = init_states
  for clip in clips:
    # Input shape: [1, 1, 224, 224, 3]
    outputs = runner(**states, image=clip)
    logits = outputs.pop('logits')[0]
    states = outputs

  probs = tf.nn.softmax(logits)
  top_k = get_top_k(probs)

  for label, prob in top_k:
    if prob * 100 >= threshold:
      print("Action : " + label + ", with probability : " + str(prob * 100) + "%")
      return

  print("Action : nothing detected")

# %%
# @title 12. Run inference

for video_item in videos_information:
  video_name = video_item[0]
  video_segments = video_item[1]
  video_segments_playable = video_item[2]

  print()
  print("Video : ", video_name)
  print(".............................")

  segment_id = 0
  for segment in video_segments:
    print("Detecting ", segment_id + 1, " ...")
    print("Time stamp from ", segment_id * seconds_per_segments, " seconds to ", (segment_id + 1) * seconds_per_segments)
    detectFirstPrint(video_segments[segment_id])
    media.show_video(video_segments_playable[segment_id], fps=video_fps)
    segment_id = segment_id + 1
