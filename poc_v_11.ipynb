# %% [markdown]
# <a href="https://colab.research.google.com/github/rifathaqueamit/poc_development/blob/develop/poc_v_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Demonstration of the POC for searching content inside video</h1>

# %% [markdown]
# Prerequisites
#
# Go through steps one by one
#
# Update : V11 (24th Oct, 2023)

# %%
# @title 1. Install dependencies
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy

# %%
# @title 2. Import dependencies
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import mediapy as media
import numpy as np
import PIL
import pandas as pd
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_hub as hub
import tqdm
import absl.logging
import random
import re
import tempfile
import ssl
import cv2
import imageio
import requests
import json
import glob

from IPython import display
from urllib import request

tf.get_logger().setLevel('ERROR')
absl.logging.set_verbosity(absl.logging.ERROR)
mpl.rcParams.update({
    'font.size': 10,
})

# %%
# @title 3. Define constants (if required)
#Common constants
input_videos_path = "input_videos"
output_videos_path = "output_videos"
video_fps = 5
seconds_per_segments = 15
threshold = 50
frames_per_video = seconds_per_segments * video_fps

#Action detection
action_frame_width = 224
action_frame_height = 224

#Object detection
object_frame_width = 320
object_frame_height = 320
class_names = [
      "person", "bicycle", "car", "motorcycle", "airplane",
      "bus", "train", "truck", "boat", "traffic light",
      "fire hydrant", "---", "stop sign", "parking meter", "bench",
      "bird", "cat", "dog", "horse", "sheep", "cow",
      "elephant", "bear", "zebra", "giraffe", "---", "backpack",
      "umbrella", "---", "---", "handbag", "tie", "suitcase", "frisbee",
      "skis", "snowboard", "sports ball", "kite", "baseball bat",
      "baseball glove", "skateboard", "surfboard", "tennis racket",
      "bottle", "---", "wine glass", "cup", "fork", "knife", "spoon",
      "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
      "carrot", "hot dog", "pizza", "donut", "cake", "chair",
      "couch", "potted plant", "bed", "---",  "dining table", "---", "---",
      "toilet", "---", "tv", "laptop", "mouse", "remote", "keyboard", "cell phone",
      "microwave", "oven", "toaster", "sink", "refrigerator", "---", "book",
      "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush", "---"
  ]

# %%
# @title 4. Get necessary files

#Create folders
if os.path.exists(input_videos_path) == False:
  os.mkdir(input_videos_path)

if os.path.exists(output_videos_path) == False:
  os.mkdir(output_videos_path)

# Clean folders
files = glob.glob('/content/' + input_videos_path + '/*')
for f in files:
  os.remove(f)

files = glob.glob('/content/' + output_videos_path + '/*')
for f in files:
  os.remove(f)

# Load models
if os.path.exists("/content/action_model.tflite") == False:
  # !wget https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/action_model.tflite

if os.path.exists("/content/object_model.tflite") == False:
  # !wget https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/object_model.tflite

# Load input videos
res = requests.get('https://github.com/rifathaqueamit/poc_development/tree/develop/input_videos')
data = json.loads(res.text)
files = data['payload']['tree']['items']

for file_item in files:
  name = file_item['name']
  path = "https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/" + name
  path = path.replace(" ", "%20")
  # !wget $path
  os.rename("/content/" + name, '/content/' + input_videos_path + '/' + name)
  print("Loaded : ", name)
# Out:
# --2023-10-24 09:48:06--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video11.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4403240 (4.2M) [application/octet-stream]
# Saving to: ‘video11.mp4’
#
# video11.mp4         100%[===================>]   4.20M  --.-KB/s    in 0.09s
#
# 2023-10-24 09:48:06 (46.4 MB/s) - ‘video11.mp4’ saved [4403240/4403240]
#
# Loaded :  video11.mp4
# --2023-10-24 09:48:06--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video12.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17911680 (17M) [application/octet-stream]
# Saving to: ‘video12.mp4’
#
# video12.mp4         100%[===================>]  17.08M  --.-KB/s    in 0.1s
#
# 2023-10-24 09:48:07 (116 MB/s) - ‘video12.mp4’ saved [17911680/17911680]
#
# Loaded :  video12.mp4
# --2023-10-24 09:48:07--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video14.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6747354 (6.4M) [application/octet-stream]
# Saving to: ‘video14.mp4’
#
# video14.mp4         100%[===================>]   6.43M  --.-KB/s    in 0.07s
#
# 2023-10-24 09:48:07 (90.9 MB/s) - ‘video14.mp4’ saved [6747354/6747354]
#
# Loaded :  video14.mp4
# --2023-10-24 09:48:07--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video15.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6480481 (6.2M) [application/octet-stream]
# Saving to: ‘video15.mp4’
#
# video15.mp4         100%[===================>]   6.18M  --.-KB/s    in 0.09s
#
# 2023-10-24 09:48:07 (67.8 MB/s) - ‘video15.mp4’ saved [6480481/6480481]
#
# Loaded :  video15.mp4
# --2023-10-24 09:48:07--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video16.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11431708 (11M) [application/octet-stream]
# Saving to: ‘video16.mp4’
#
# video16.mp4         100%[===================>]  10.90M  --.-KB/s    in 0.1s
#
# 2023-10-24 09:48:08 (96.6 MB/s) - ‘video16.mp4’ saved [11431708/11431708]
#
# Loaded :  video16.mp4
# --2023-10-24 09:48:08--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video17.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11986299 (11M) [application/octet-stream]
# Saving to: ‘video17.mp4’
#
# video17.mp4         100%[===================>]  11.43M  --.-KB/s    in 0.1s
#
# 2023-10-24 09:48:08 (105 MB/s) - ‘video17.mp4’ saved [11986299/11986299]
#
# Loaded :  video17.mp4
# --2023-10-24 09:48:08--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video2.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8124833 (7.7M) [application/octet-stream]
# Saving to: ‘video2.mp4’
#
# video2.mp4          100%[===================>]   7.75M  --.-KB/s    in 0.08s
#
# 2023-10-24 09:48:09 (91.5 MB/s) - ‘video2.mp4’ saved [8124833/8124833]
#
# Loaded :  video2.mp4
# --2023-10-24 09:48:09--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video3.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3474961 (3.3M) [application/octet-stream]
# Saving to: ‘video3.mp4’
#
# video3.mp4          100%[===================>]   3.31M  --.-KB/s    in 0.05s
#
# 2023-10-24 09:48:09 (72.0 MB/s) - ‘video3.mp4’ saved [3474961/3474961]
#
# Loaded :  video3.mp4
# --2023-10-24 09:48:10--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video4.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12795098 (12M) [application/octet-stream]
# Saving to: ‘video4.mp4’
#
# video4.mp4          100%[===================>]  12.20M  81.3MB/s    in 0.2s
#
# 2023-10-24 09:48:10 (81.3 MB/s) - ‘video4.mp4’ saved [12795098/12795098]
#
# Loaded :  video4.mp4
# --2023-10-24 09:48:10--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video6.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9240173 (8.8M) [application/octet-stream]
# Saving to: ‘video6.mp4’
#
# video6.mp4          100%[===================>]   8.81M  --.-KB/s    in 0.08s
#
# 2023-10-24 09:48:10 (111 MB/s) - ‘video6.mp4’ saved [9240173/9240173]
#
# Loaded :  video6.mp4
# --2023-10-24 09:48:10--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video8.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13779988 (13M) [application/octet-stream]
# Saving to: ‘video8.mp4’
#
# video8.mp4          100%[===================>]  13.14M  --.-KB/s    in 0.1s
#
# 2023-10-24 09:48:11 (119 MB/s) - ‘video8.mp4’ saved [13779988/13779988]
#
# Loaded :  video8.mp4
# --2023-10-24 09:48:11--  https://raw.githubusercontent.com/rifathaqueamit/poc_development/develop/input_videos/video9.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3491149 (3.3M) [application/octet-stream]
# Saving to: ‘video9.mp4’
#
# video9.mp4          100%[===================>]   3.33M  --.-KB/s    in 0.05s
#
# 2023-10-24 09:48:11 (71.3 MB/s) - ‘video9.mp4’ saved [3491149/3491149]
#
# Loaded :  video9.mp4

# %%
# @title 5. Helper functions

# Download Kinetics 600 label map
# !wget https://raw.githubusercontent.com/tensorflow/models/f8af2291cced43fc9f1d9b41ddbf772ae7b0d7d2/official/projects/movinet/files/kinetics_600_labels.txt -O labels.txt -q

with tf.io.gfile.GFile('labels.txt') as f:
  lines = f.readlines()
  KINETICS_600_LABELS_LIST = [line.strip() for line in lines]
  KINETICS_600_LABELS = tf.constant(KINETICS_600_LABELS_LIST)

def get_top_k(probs, k=5, label_map=KINETICS_600_LABELS):
  """Outputs the top k model labels and probabilities on the given video."""
  top_predictions = tf.argsort(probs, axis=-1, direction='DESCENDING')[:k]
  top_labels = tf.gather(label_map, top_predictions, axis=-1)
  top_labels = [label.decode('utf8') for label in top_labels.numpy()]
  top_probs = tf.gather(probs, top_predictions, axis=-1).numpy()
  return tuple(zip(top_labels, top_probs))

# Utilities to open video files using CV2
def crop_center_square(frame):
  y, x = frame.shape[0:2]
  min_dim = min(y, x)
  start_x = (x // 2) - (min_dim // 2)
  start_y = (y // 2) - (min_dim // 2)
  return frame[start_y:start_y+min_dim,start_x:start_x+min_dim]

def load_video(path, max_frames=0, resize=(object_frame_width, object_frame_height)):
  cap = cv2.VideoCapture(path)
  frames = []
  try:
    while True:
      ret, frame = cap.read()
      if not ret:
        break
      frame = crop_center_square(frame)
      frame = cv2.resize(frame, resize)
      frame = frame[:, :, [2, 1, 0]]
      frames.append(frame)

      if len(frames) == max_frames:
        break
  finally:
    cap.release()
  return np.array(frames)

# %%
# @title 6. Load pre-trained model
# Create the interpreter and signature runner
action_interpreter = tf.lite.Interpreter(model_path="action_model.tflite")
action_runner = action_interpreter.get_signature_runner()

object_interpreter = tf.lite.Interpreter(model_path="object_model.tflite")
object_interpreter.allocate_tensors()

# %%
# @title 7. Collect input videos (Mp4 only)
input_videos = []

for file in os.listdir("input_videos"):
    if file.endswith(".mp4"):
        input_videos.append(file)

if len(input_videos) == 0:
  print("There is no input videos")
else:
  print(input_videos)
# Out:
# ['video9.mp4', 'video2.mp4', 'video12.mp4', 'video8.mp4', 'video14.mp4', 'video17.mp4', 'video16.mp4', 'video6.mp4', 'video4.mp4', 'video15.mp4', 'video3.mp4', 'video11.mp4']

# %%
# @title 8. Convert the input mp4 video into AVI format
output_videos = []
for input_video in input_videos:
  input_path = input_videos_path + "/" + input_video
  path, filename_ext = os.path.split(input_path)
  filename = os.path.splitext(filename_ext)
  output_path = output_videos_path + "/" + filename[0] + ".avi"
  if os.path.exists(output_path):
    os.remove(output_path)
  print("Input : ", input_path)
  print("Output : ", output_path)
  # !ffmpeg -i $input_path -filter:v fps=$video_fps $output_path
  output_videos.append(output_path)
# Out:
# Input :  input_videos/video9.mp4
# Output :  output_videos/video9.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video9.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-12-12T09:49:13.000000Z
#   Duration: 00:00:21.66, start: 0.000000, bitrate: 1289 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 720x1280 [SAR 1:1 DAR 9:16], 1157 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2022-12-12T09:49:13.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/12/2022.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-12-12T09:49:13.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/12/2022.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video9.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 720x1280 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2022-12-12T09:49:13.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/12/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2022-12-12T09:49:13.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/12/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  108 fps= 46 q=24.8 Lsize=    1251kB time=00:00:21.65 bitrate= 473.4kbits/s speed=9.14x
# video:880kB audio:339kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.614182%
# Input :  input_videos/video2.mp4
# Output :  output_videos/video2.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-12-29T07:44:36.000000Z
#   Duration: 00:00:58.96, start: 0.000000, bitrate: 1102 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, smpte170m/bt470bg/bt709), 720x1280 [SAR 1:1 DAR 9:16], 970 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-12-29T07:44:36.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/28/2022.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-12-29T07:44:36.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/28/2022.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video2.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, smpte170m/bt470bg/bt709, progressive), 720x1280 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2022-12-29T07:44:36.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/28/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2022-12-29T07:44:36.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 12/28/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  295 fps= 45 q=31.0 Lsize=    3689kB time=00:00:59.00 bitrate= 512.2kbits/s speed=8.91x
# video:2697kB audio:922kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.930538%
# Input :  input_videos/video12.mp4
# Output :  output_videos/video12.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video12.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-06-12T04:12:37.000000Z
#   Duration: 00:00:58.96, start: 0.000000, bitrate: 2430 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 720x1280 [SAR 1:1 DAR 9:16], 2298 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2023-06-12T04:12:37.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/11/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-06-12T04:12:37.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/11/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video12.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 720x1280 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2023-06-12T04:12:37.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/11/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2023-06-12T04:12:37.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/11/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  295 fps= 29 q=31.0 Lsize=    5190kB time=00:00:59.00 bitrate= 720.6kbits/s speed=5.85x
# video:4198kB audio:922kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.364478%
# Input :  input_videos/video8.mp4
# Output :  output_videos/video8.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video8.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-14T08:04:59.000000Z
#   Duration: 00:00:50.29, start: 0.000000, bitrate: 2191 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 2060 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-14T08:04:59.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/14/2022.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-14T08:04:59.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/14/2022.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video8.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2022-05-14T08:04:59.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/14/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2022-05-14T08:04:59.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/14/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  251 fps= 33 q=31.0 Lsize=    3854kB time=00:00:50.28 bitrate= 627.9kbits/s speed=6.71x
# video:3007kB audio:787kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.609366%
# Input :  input_videos/video14.mp4
# Output :  output_videos/video14.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video14.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2021-07-27T21:37:44.000000Z
#     com.android.version: 13
#   Duration: 00:00:15.33, start: 0.000000, bitrate: 3520 kb/s
#   Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt470bg/bt470bg/smpte170m), 1280x720, 3398 kb/s, 30 fps, 30 tbr, 90k tbn, 180k tbc (default)
#     Metadata:
#       creation_time   : 2023-08-14T10:12:59.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2023-08-14T10:12:59.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video14.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     com.android.version: 13
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt470bg/bt470bg/smpte170m, progressive), 1280x720, q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2023-08-14T10:12:59.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2023-08-14T10:12:59.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=   77 fps= 35 q=31.0 Lsize=    1411kB time=00:00:15.40 bitrate= 750.6kbits/s speed=6.94x
# video:1145kB audio:240kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.916547%
# Input :  input_videos/video17.mp4
# Output :  output_videos/video17.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video17.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-08-14T09:05:50.000000Z
#   Duration: 00:00:47.25, start: 0.000000, bitrate: 2029 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 720x1280 [SAR 1:1 DAR 9:16], 1897 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2023-08-14T09:05:50.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/14/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-08-14T09:05:50.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/14/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video17.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 720x1280 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2023-08-14T09:05:50.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/14/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2023-08-14T09:05:50.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/14/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  236 fps= 36 q=31.0 Lsize=    2977kB time=00:00:47.22 bitrate= 516.4kbits/s speed=7.14x
# video:2180kB audio:739kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.984189%
# Input :  input_videos/video16.mp4
# Output :  output_videos/video16.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video16.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-08-05T10:19:10.000000Z
#   Duration: 00:00:37.50, start: 0.000000, bitrate: 2438 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 720x1280 [SAR 1:1 DAR 9:16], 2306 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2023-08-05T10:19:10.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/05/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-08-05T10:19:10.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/05/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video16.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 720x1280 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2023-08-05T10:19:10.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/05/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2023-08-05T10:19:10.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/05/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  188 fps= 26 q=31.0 Lsize=    3072kB time=00:00:37.60 bitrate= 669.4kbits/s speed=5.29x
# video:2438kB audio:587kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.588077%
# Input :  input_videos/video6.mp4
# Output :  output_videos/video6.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video6.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-09-01T01:11:25.000000Z
#   Duration: 00:02:02.83, start: 0.000000, bitrate: 601 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 470 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       creation_time   : 2023-09-01T01:11:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/31/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-09-01T01:11:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/31/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video6.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2023-09-01T01:11:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/31/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2023-09-01T01:11:25.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/31/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  614 fps= 45 q=31.0 Lsize=    5806kB time=00:02:02.82 bitrate= 387.2kbits/s speed=9.01x
# video:3751kB audio:1920kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.379231%
# Input :  input_videos/video4.mp4
# Output :  output_videos/video4.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video4.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-05-26T06:51:55.000000Z
#   Duration: 00:01:50.74, start: 0.000000, bitrate: 924 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 792 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2023-05-26T06:51:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/25/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-26T06:51:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/25/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video4.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2023-05-26T06:51:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/25/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2023-05-26T06:51:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/25/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  554 fps= 42 q=31.0 Lsize=    5324kB time=00:01:50.80 bitrate= 393.6kbits/s speed=8.46x
# video:3471kB audio:1731kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.357459%
# Input :  input_videos/video15.mp4
# Output :  output_videos/video15.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video15.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-06-18T03:01:18.000000Z
#   Duration: 00:00:27.40, start: 0.000000, bitrate: 1892 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 720x1280 [SAR 1:1 DAR 9:16], 1760 kb/s, 27.46 fps, 27.46 tbr, 13728 tbn, 54.91 tbc (default)
#     Metadata:
#       creation_time   : 2023-06-18T03:01:18.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/17/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-06-18T03:01:18.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/17/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video15.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 720x1280 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2023-06-18T03:01:18.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/17/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2023-06-18T03:01:18.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 06/17/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=  137 fps= 39 q=31.0 Lsize=    1909kB time=00:00:27.40 bitrate= 570.7kbits/s speed= 7.7x
# video:1443kB audio:429kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.015831%
# Input :  input_videos/video3.mp4
# Output :  output_videos/video3.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video3.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-08-24T12:21:35.000000Z
#   Duration: 00:00:15.05, start: 0.000000, bitrate: 1847 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 720x1280 [SAR 1:1 DAR 9:16], 1716 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-08-24T12:21:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/24/2022.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-08-24T12:21:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/24/2022.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video3.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 720x1280 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2022-08-24T12:21:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/24/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2022-08-24T12:21:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 08/24/2022.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=   75 fps= 28 q=31.0 Lsize=    1130kB time=00:00:15.02 bitrate= 616.3kbits/s speed=5.65x
# video:869kB audio:236kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.274995%
# Input :  input_videos/video11.mp4
# Output :  output_videos/video11.avi
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input_videos/video11.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2023-02-04T21:23:44.000000Z
#   Duration: 00:00:15.19, start: 0.000000, bitrate: 2319 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 720x1280 [SAR 1:1 DAR 9:16], 2190 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2023-02-04T21:23:44.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/04/2023.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-02-04T21:23:44.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/04/2023.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mpeg4 (native))
#   Stream #0:1 -> #0:1 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'output_videos/video11.avi':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Video: mpeg4 (FMP4 / 0x34504D46), yuv420p(tv, bt709, progressive), 720x1280 [SAR 1:1 DAR 9:16], q=2-31, 200 kb/s, 5 fps, 5 tbn (default)
#     Metadata:
#       creation_time   : 2023-02-04T21:23:44.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/04/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: mp3 (U[0][0][0] / 0x0055), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       creation_time   : 2023-02-04T21:23:44.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 02/04/2023.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# frame=   76 fps= 18 q=31.0 Lsize=    1511kB time=00:00:15.20 bitrate= 814.4kbits/s speed=3.55x
# video:1248kB audio:238kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.702063%

# %%
# @title 9. Load the videos
action_videos = []
object_videos = []
for url in output_videos:
  object_video = load_video(url)
  action_video = load_video(url, resize=(action_frame_width, action_frame_height)) / 255
  # media.show_video(loaded_video, fps=video_fps)

  print("path : ", url)
  print("action video frames count, width, height, color : ", action_video.shape)
  print("object video frames count, width, height, color : ", object_video.shape)

  action_videos.append((url, action_video))
  object_videos.append((url, object_video))
# Out:
# path :  output_videos/video9.avi
# action video frames count, width, height, color :  (108, 224, 224, 3)
# object video frames count, width, height, color :  (108, 320, 320, 3)
# path :  output_videos/video2.avi
# action video frames count, width, height, color :  (295, 224, 224, 3)
# object video frames count, width, height, color :  (295, 320, 320, 3)
# path :  output_videos/video12.avi
# action video frames count, width, height, color :  (295, 224, 224, 3)
# object video frames count, width, height, color :  (295, 320, 320, 3)
# path :  output_videos/video8.avi
# action video frames count, width, height, color :  (251, 224, 224, 3)
# object video frames count, width, height, color :  (251, 320, 320, 3)
# path :  output_videos/video14.avi
# action video frames count, width, height, color :  (77, 224, 224, 3)
# object video frames count, width, height, color :  (77, 320, 320, 3)
# path :  output_videos/video17.avi
# action video frames count, width, height, color :  (236, 224, 224, 3)
# object video frames count, width, height, color :  (236, 320, 320, 3)
# path :  output_videos/video16.avi
# action video frames count, width, height, color :  (188, 224, 224, 3)
# object video frames count, width, height, color :  (188, 320, 320, 3)
# path :  output_videos/video6.avi
# action video frames count, width, height, color :  (614, 224, 224, 3)
# object video frames count, width, height, color :  (614, 320, 320, 3)
# path :  output_videos/video4.avi
# action video frames count, width, height, color :  (554, 224, 224, 3)
# object video frames count, width, height, color :  (554, 320, 320, 3)
# path :  output_videos/video15.avi
# action video frames count, width, height, color :  (137, 224, 224, 3)
# object video frames count, width, height, color :  (137, 320, 320, 3)
# path :  output_videos/video3.avi
# action video frames count, width, height, color :  (75, 224, 224, 3)
# object video frames count, width, height, color :  (75, 320, 320, 3)
# path :  output_videos/video11.avi
# action video frames count, width, height, color :  (76, 224, 224, 3)
# object video frames count, width, height, color :  (76, 320, 320, 3)

# %%
# @title 10. Separate the videos in small segments
def separateVideoInSegments(url, video_frames):
  print("separateVideoInSegments() : ", url)
  video_segments = []
  video_segments_playable = []

  for idx, frame in enumerate(video_frames):
    video_id = int(idx / frames_per_video)
    try:
      f32_frame = tf.cast(frame, tf.float32)
      video_segments[video_id].append(f32_frame)
      video_segments_playable[video_id].append(frame)
    except IndexError:
      video_segments.append([f32_frame])
      video_segments_playable.append([frame])

  for idx, segment in enumerate(video_segments):
    print("Segment ", idx+1, ", total frames : ", len(segment))

  return (url, video_segments, video_segments_playable)

# %%
action_videos_segments = []
object_videos_segments = []
video_segments_detection = {}
object_segments_detection = {}

# Action videos
for url, video in action_videos:
  action_videos_segments.append(separateVideoInSegments(url, video))

for url, video in object_videos:
  object_videos_segments.append(separateVideoInSegments(url, video))

for url, video in action_videos:
  video_segments_detection[url] = []
  object_segments_detection[url] = []
# Out:
# separateVideoInSegments() :  output_videos/video9.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  33
# separateVideoInSegments() :  output_videos/video2.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  70
# separateVideoInSegments() :  output_videos/video12.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  70
# separateVideoInSegments() :  output_videos/video8.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  26
# separateVideoInSegments() :  output_videos/video14.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  2
# separateVideoInSegments() :  output_videos/video17.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  11
# separateVideoInSegments() :  output_videos/video16.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  38
# separateVideoInSegments() :  output_videos/video6.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  75
# Segment  5 , total frames :  75
# Segment  6 , total frames :  75
# Segment  7 , total frames :  75
# Segment  8 , total frames :  75
# Segment  9 , total frames :  14
# separateVideoInSegments() :  output_videos/video4.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  75
# Segment  5 , total frames :  75
# Segment  6 , total frames :  75
# Segment  7 , total frames :  75
# Segment  8 , total frames :  29
# separateVideoInSegments() :  output_videos/video15.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  62
# separateVideoInSegments() :  output_videos/video3.avi
# Segment  1 , total frames :  75
# separateVideoInSegments() :  output_videos/video11.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  1
# separateVideoInSegments() :  output_videos/video9.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  33
# separateVideoInSegments() :  output_videos/video2.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  70
# separateVideoInSegments() :  output_videos/video12.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  70
# separateVideoInSegments() :  output_videos/video8.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  26
# separateVideoInSegments() :  output_videos/video14.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  2
# separateVideoInSegments() :  output_videos/video17.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  11
# separateVideoInSegments() :  output_videos/video16.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  38
# separateVideoInSegments() :  output_videos/video6.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  75
# Segment  5 , total frames :  75
# Segment  6 , total frames :  75
# Segment  7 , total frames :  75
# Segment  8 , total frames :  75
# Segment  9 , total frames :  14
# separateVideoInSegments() :  output_videos/video4.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  75
# Segment  3 , total frames :  75
# Segment  4 , total frames :  75
# Segment  5 , total frames :  75
# Segment  6 , total frames :  75
# Segment  7 , total frames :  75
# Segment  8 , total frames :  29
# separateVideoInSegments() :  output_videos/video15.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  62
# separateVideoInSegments() :  output_videos/video3.avi
# Segment  1 , total frames :  75
# separateVideoInSegments() :  output_videos/video11.avi
# Segment  1 , total frames :  75
# Segment  2 , total frames :  1

# %%
# @title 11. Define the detect function for video classification
def detectFirstPrint(video):
  init_states = {
    name: tf.zeros(x['shape'], dtype=x['dtype'])
    for name, x in action_runner.get_input_details().items()
  }
  del init_states['image']

  clips = video
  states = init_states
  for clip in clips:
    # Input shape: [1, 1, 224, 224, 3]
    outputs = action_runner(**states, image=clip)
    logits = outputs.pop('logits')[0]
    states = outputs

  probs = tf.nn.softmax(logits)
  top_k = get_top_k(probs)

  for label, prob in top_k:
    if prob * 100 >= threshold:
      print("     Action : " + label + ", with probability : " + str(prob * 100) + "%")
      video_segments_detection[url].append(label)
      return

  print("     Action : nothing detected")
  video_segments_detection[url].append("nothing")

# %%
# @title 12. Run inference for video classification

# Video action classification
for video in action_videos_segments:
  url = video[0]
  video_segments = video[1]
  video_segments_playable = video[2]

  video_segments_detection[url].clear()

  print("Url : ", url)
  print(".............................")

  segment_id = 0
  for segment in video_segments:
    segment_start_time = segment_id * seconds_per_segments
    segment_end_time = (segment_id + 1) * seconds_per_segments
    print("Segment : ", segment_id+1, " , start : ", segment_start_time, " , end : ", segment_end_time)
    detectFirstPrint(video_segments[segment_id])
    # media.show_video(video_segments_playable[segment_id], fps=video_fps)
    segment_id = segment_id + 1
# Out:
# Url :  output_videos/video9.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : playing tennis, with probability : 56.42029047012329%
# Segment :  2  , start :  15  , end :  30
#      Action : nothing detected
# Url :  output_videos/video2.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : shooting goal (soccer), with probability : 65.00195860862732%
# Segment :  2  , start :  15  , end :  30
#      Action : shooting goal (soccer), with probability : 91.71982407569885%
# Segment :  3  , start :  30  , end :  45
#      Action : shooting goal (soccer), with probability : 77.54311561584473%
# Segment :  4  , start :  45  , end :  60
#      Action : shooting goal (soccer), with probability : 64.62652087211609%
# Url :  output_videos/video12.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : punching person (boxing), with probability : 92.71236062049866%
# Segment :  2  , start :  15  , end :  30
#      Action : punching person (boxing), with probability : 91.71856045722961%
# Segment :  3  , start :  30  , end :  45
#      Action : punching person (boxing), with probability : 86.89768314361572%
# Segment :  4  , start :  45  , end :  60
#      Action : punching person (boxing), with probability : 80.2668809890747%
# Url :  output_videos/video8.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : nothing detected
# Segment :  2  , start :  15  , end :  30
#      Action : riding or walking with horse, with probability : 81.33664727210999%
# Segment :  3  , start :  30  , end :  45
#      Action : riding or walking with horse, with probability : 81.88372850418091%
# Segment :  4  , start :  45  , end :  60
#      Action : riding or walking with horse, with probability : 98.37762713432312%
# Url :  output_videos/video14.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : salsa dancing, with probability : 83.327716588974%
# Segment :  2  , start :  15  , end :  30
#      Action : nothing detected
# Url :  output_videos/video17.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : scrambling eggs, with probability : 93.9249575138092%
# Segment :  2  , start :  15  , end :  30
#      Action : nothing detected
# Segment :  3  , start :  30  , end :  45
#      Action : making a cake, with probability : 78.55285406112671%
# Segment :  4  , start :  45  , end :  60
#      Action : making a cake, with probability : 85.11624932289124%
# Url :  output_videos/video16.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : nothing detected
# Segment :  2  , start :  15  , end :  30
#      Action : nothing detected
# Segment :  3  , start :  30  , end :  45
#      Action : nothing detected
# Url :  output_videos/video6.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : nothing detected
# Segment :  2  , start :  15  , end :  30
#      Action : nothing detected
# Segment :  3  , start :  30  , end :  45
#      Action : motorcycling, with probability : 60.10374426841736%
# Segment :  4  , start :  45  , end :  60
#      Action : nothing detected
# Segment :  5  , start :  60  , end :  75
#      Action : nothing detected
# Segment :  6  , start :  75  , end :  90
#      Action : nothing detected
# Segment :  7  , start :  90  , end :  105
#      Action : nothing detected
# Segment :  8  , start :  105  , end :  120
#      Action : nothing detected
# Segment :  9  , start :  120  , end :  135
#      Action : nothing detected
# Url :  output_videos/video4.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : driving car, with probability : 50.67536234855652%
# Segment :  2  , start :  15  , end :  30
#      Action : driving car, with probability : 99.25750494003296%
# Segment :  3  , start :  30  , end :  45
#      Action : driving car, with probability : 96.1687982082367%
# Segment :  4  , start :  45  , end :  60
#      Action : driving car, with probability : 98.539137840271%
# Segment :  5  , start :  60  , end :  75
#      Action : driving car, with probability : 84.8975121974945%
# Segment :  6  , start :  75  , end :  90
#      Action : driving car, with probability : 75.01294016838074%
# Segment :  7  , start :  90  , end :  105
#      Action : driving car, with probability : 98.71808886528015%
# Segment :  8  , start :  105  , end :  120
#      Action : nothing detected
# Url :  output_videos/video15.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : nothing detected
# Segment :  2  , start :  15  , end :  30
#      Action : nothing detected
# Url :  output_videos/video3.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : chopping vegetables, with probability : 98.12910556793213%
# Url :  output_videos/video11.avi
# .............................
# Segment :  1  , start :  0  , end :  15
#      Action : nothing detected
# Segment :  2  , start :  15  , end :  30
#      Action : nothing detected

# %%
# @title 13. Prepare details for object interpreter
object_input_details = object_interpreter.get_input_details()
object_output_details = object_interpreter.get_output_details()
object_input_shape = object_input_details[0]['shape'][1:3]

# %%
# @title 14. Define object detection function
def detectObjects(segmentId, video):
  all_detections = set()
  for idx, frame in enumerate(video):
    if idx % video_fps == 0:
      # detected_objects_in_frame = []
      #plt.imshow(frame / 255)
      #plt.axis('off')
      #plt.show()
      int_frame = np.array(frame, dtype=np.uint8)
      int_frame = np.expand_dims(int_frame, axis=0)
      object_interpreter.set_tensor(object_input_details[0]['index'], int_frame)
      object_interpreter.invoke()
      classes = object_interpreter.get_tensor(object_output_details[1]['index'])
      scores = object_interpreter.get_tensor(object_output_details[2]['index'])
      num_detections = int(object_interpreter.get_tensor(object_output_details[3]['index']))

      detections = set()

      for k in range(num_detections):
        if scores[0, k] > (threshold / float(100)):
            class_id = int(classes[0, k])
            class_name = class_names[class_id]
            # confidence = scores[0, k]
            # label = f"class name = {class_name}, class id = {class_id + 1}, confidence = {confidence:.2f}"
            # print(label)
            # detected_objects_in_frame.append(label)
            detections.add(class_name)
      # print("     Frame : ", idx, ", Detections : ", detections)
      for item in detections:
        all_detections.add(item)
  print("Segment detections : ", all_detections)
  return all_detections

# %%
# @title 15. Run inference for object detection
for video in object_videos_segments:
  url = video[0]
  video_segments = video[1]
  video_segments_playable = video[2]

  object_segments_detection[url].clear()

  print("Url : ", url)
  print(".............................")

  segment_id = 0
  for segment in video_segments:
    segment_start_time = segment_id * seconds_per_segments
    segment_end_time = (segment_id + 1) * seconds_per_segments
    print("Segment : ", segment_id+1, " , start : ", segment_start_time, " , end : ", segment_end_time)
    detections = detectObjects(segment_id, video_segments[segment_id])
    object_segments_detection[url].append(detections)
    # media.show_video(video_segments_playable[segment_id], fps=video_fps)
    segment_id = segment_id + 1
# Out:
# Url :  output_videos/video9.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'person', 'tennis racket'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  {'person', 'cat'}
# Url :  output_videos/video2.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'person', 'fire hydrant', 'bird', 'bottle'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  {'person', 'dog'}
# Segment :  3  , start :  30  , end :  45
# Segment detections :  {'person'}
# Segment :  4  , start :  45  , end :  60
# Segment detections :  {'person', 'bottle'}
# Url :  output_videos/video12.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'person', 'teddy bear'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  {'person', 'tv'}
# Segment :  3  , start :  30  , end :  45
# Segment detections :  {'person'}
# Segment :  4  , start :  45  , end :  60
# Segment detections :  {'person'}
# Url :  output_videos/video8.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'car', 'person', 'dog', 'horse'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  {'person', 'horse'}
# Segment :  3  , start :  30  , end :  45
# Segment detections :  {'person', 'horse'}
# Segment :  4  , start :  45  , end :  60
# Segment detections :  {'person', 'horse'}
# Url :  output_videos/video14.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'car', 'person', 'suitcase'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  {'person'}
# Url :  output_videos/video17.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'umbrella'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  {'donut', 'umbrella', 'dining table'}
# Segment :  3  , start :  30  , end :  45
# Segment detections :  {'donut', 'cake'}
# Segment :  4  , start :  45  , end :  60
# Segment detections :  {'cake'}
# Url :  output_videos/video16.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'car', 'person', 'bus', 'parking meter'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  {'car', 'person', 'parking meter', 'backpack'}
# Segment :  3  , start :  30  , end :  45
# Segment detections :  {'car', 'person', 'backpack'}
# Url :  output_videos/video6.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  set()
# Segment :  2  , start :  15  , end :  30
# Segment detections :  set()
# Segment :  3  , start :  30  , end :  45
# Segment detections :  {'person'}
# Segment :  4  , start :  45  , end :  60
# Segment detections :  {'car', 'person', 'truck'}
# Segment :  5  , start :  60  , end :  75
# Segment detections :  {'person'}
# Segment :  6  , start :  75  , end :  90
# Segment detections :  {'tv', 'cat'}
# Segment :  7  , start :  90  , end :  105
# Segment detections :  {'person'}
# Segment :  8  , start :  105  , end :  120
# Segment detections :  set()
# Segment :  9  , start :  120  , end :  135
# Segment detections :  set()
# Url :  output_videos/video4.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'car'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  {'car'}
# Segment :  3  , start :  30  , end :  45
# Segment detections :  {'car', 'boat'}
# Segment :  4  , start :  45  , end :  60
# Segment detections :  {'car', 'airplane'}
# Segment :  5  , start :  60  , end :  75
# Segment detections :  {'car', 'airplane'}
# Segment :  6  , start :  75  , end :  90
# Segment detections :  {'car'}
# Segment :  7  , start :  90  , end :  105
# Segment detections :  {'car'}
# Segment :  8  , start :  105  , end :  120
# Segment detections :  {'car'}
# Url :  output_videos/video15.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'person', 'clock'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  {'skateboard', 'person', 'clock'}
# Url :  output_videos/video3.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'person', 'knife', 'dining table'}
# Url :  output_videos/video11.avi
# .............................
# Segment :  1  , start :  0  , end :  15
# Segment detections :  {'person', 'train'}
# Segment :  2  , start :  15  , end :  30
# Segment detections :  set()

# %%
# @title 16. Collect everything together
individual_segment_wise_detections = []
video_segment_detections = {}

for url, video in action_videos:
  video_segment_detections[url] = []

for url, detections in video_segments_detection.items():
  print(detections)
  individual_segment_wise_detections.clear()
  segment_id = 0
  for dect in detections:
    if dect != "nothing":
      individual_segment_wise_detections.append({dect})
    else:
      individual_segment_wise_detections.append(set())
    for setItem in object_segments_detection[url][segment_id]:
      individual_segment_wise_detections[len(individual_segment_wise_detections) - 1].add(setItem)
    segment_id = segment_id + 1
  video_segment_detections[url] = individual_segment_wise_detections.copy()




print("Videos detections : ")
print(video_segment_detections)
# Out:
# ['playing tennis', 'nothing']
# ['shooting goal (soccer)', 'shooting goal (soccer)', 'shooting goal (soccer)', 'shooting goal (soccer)']
# ['punching person (boxing)', 'punching person (boxing)', 'punching person (boxing)', 'punching person (boxing)']
# ['nothing', 'riding or walking with horse', 'riding or walking with horse', 'riding or walking with horse']
# ['salsa dancing', 'nothing']
# ['scrambling eggs', 'nothing', 'making a cake', 'making a cake']
# ['nothing', 'nothing', 'nothing']
# ['nothing', 'nothing', 'motorcycling', 'nothing', 'nothing', 'nothing', 'nothing', 'nothing', 'nothing']
# ['driving car', 'driving car', 'driving car', 'driving car', 'driving car', 'driving car', 'driving car', 'nothing']
# ['nothing', 'nothing']
# ['chopping vegetables']
# ['nothing', 'nothing']
# Videos detections :
# {'output_videos/video9.avi': [{'person', 'tennis racket', 'playing tennis'}, {'person', 'cat'}], 'output_videos/video2.avi': [{'bird', 'bottle', 'fire hydrant', 'shooting goal (soccer)', 'person'}, {'dog', 'person', 'shooting goal (soccer)'}, {'person', 'shooting goal (soccer)'}, {'person', 'shooting goal (soccer)', 'bottle'}], 'output_videos/video12.avi': [{'person', 'teddy bear', 'punching person (boxing)'}, {'person', 'tv', 'punching person (boxing)'}, {'person', 'punching person (boxing)'}, {'person', 'punching person (boxing)'}], 'output_videos/video8.avi': [{'car', 'person', 'dog', 'horse'}, {'person', 'riding or walking with horse', 'horse'}, {'person', 'riding or walking with horse', 'horse'}, {'person', 'riding or walking with horse', 'horse'}], 'output_videos/video14.avi': [{'car', 'salsa dancing', 'person', 'suitcase'}, {'person'}], 'output_videos/video17.avi': [{'umbrella', 'scrambling eggs'}, {'donut', 'umbrella', 'dining table'}, {'donut', 'making a cake', 'cake'}, {'making a cake', 'cake'}], 'output_videos/video16.avi': [{'car', 'person', 'bus', 'parking meter'}, {'car', 'person', 'parking meter', 'backpack'}, {'car', 'person', 'backpack'}], 'output_videos/video6.avi': [set(), set(), {'motorcycling', 'person'}, {'car', 'person', 'truck'}, {'person'}, {'tv', 'cat'}, {'person'}, set(), set()], 'output_videos/video4.avi': [{'car', 'driving car'}, {'car', 'driving car'}, {'car', 'boat', 'driving car'}, {'car', 'airplane', 'driving car'}, {'car', 'airplane', 'driving car'}, {'car', 'driving car'}, {'car', 'driving car'}, {'car'}], 'output_videos/video15.avi': [{'person', 'clock'}, {'skateboard', 'person', 'clock'}], 'output_videos/video3.avi': [{'person', 'knife', 'chopping vegetables', 'dining table'}], 'output_videos/video11.avi': [{'person', 'train'}, set()]}

# %%
# @title 17. Some more utilities
def searchAtleastOneTerm(terms, text):
  for term in terms:
    if term in text:
      return True
  return False

def searchAllTerms(terms, text):
  found_terms = 0
  for term in terms:
    if term in text:
      found_terms = found_terms + 1
  if found_terms == len(terms):
    print(found_terms)
    return True
  return False

# %%
# @title 18. Demonstration by video
search = "soccer playing" # @param {type:"string"}
search_terms = search.lower().split()

if len(search_terms) > 0:
  found_videos = []
  for url, detections in video_segment_detections.items():
    for segment in detections:
      for item in segment:
        if searchAtleastOneTerm(search_terms, item):
          found_videos.append(url)
      else:
        continue
      break
    else:
      continue
    break
  for url, video in object_videos:
    for item in found_videos:
      if url == item:
        media.show_video(video, fps=video_fps)
        break
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="320" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="320" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
